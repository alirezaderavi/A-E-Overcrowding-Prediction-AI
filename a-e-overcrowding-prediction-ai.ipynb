# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/alirezaderavi98/a-and-e-overcrowding-monthly-nhs/Monthly-AE-December-2024.csv
# /kaggle/input/datasets/alirezaderavi98/a-and-e-overcrowding-monthly-nhs/Monthly-AE-January-2025.csv
# /kaggle/input/datasets/alirezaderavi98/a-and-e-overcrowding-monthly-nhs/Monthly-AE-May-2024.csv
# /kaggle/input/datasets/alirezaderavi98/a-and-e-overcrowding-monthly-nhs/Monthly-AE-November-2024-revised.csv
# /kaggle/input/datasets/alirezaderavi98/a-and-e-overcrowding-monthly-nhs/Monthly-AE-June-2024.csv
# /kaggle/input/datasets/alirezaderavi98/a-and-e-overcrowding-monthly-nhs/Monthly-AE-October-2024-revised.csv
# /kaggle/input/datasets/alirezaderavi98/a-and-e-overcrowding-monthly-nhs/Monthly-AE-July-2024-revised.csv
# /kaggle/input/datasets/alirezaderavi98/a-and-e-overcrowding-monthly-nhs/Monthly-AE-February-2025-revised.csv
# /kaggle/input/datasets/alirezaderavi98/a-and-e-overcrowding-monthly-nhs/Monthly-AE-March-2025.csv
# /kaggle/input/datasets/alirezaderavi98/a-and-e-overcrowding-monthly-nhs/Monthly-AE-April-2024-revised.csv
# /kaggle/input/datasets/alirezaderavi98/a-and-e-overcrowding-monthly-nhs/Monthly-AE-September-2024.csv
# /kaggle/input/datasets/alirezaderavi98/a-and-e-overcrowding-monthly-nhs/Monthly-AE-August-2024.csv

# %%
df = pd.read_csv("/kaggle/input/datasets/alirezaderavi98/a-and-e-overcrowding-monthly-nhs/Monthly-AE-April-2024-revised.csv")
df.columns
# Out:
# Index(['Period', 'Org Code', 'Parent Org', 'Org name',
#        'A&E attendances Type 1', 'A&E attendances Type 2',
#        'A&E attendances Other A&E Department',
#        'A&E attendances Booked Appointments Type 1',
#        'A&E attendances Booked Appointments Type 2',
#        'A&E attendances Booked Appointments Other Department',
#        'Attendances over 4hrs Type 1', 'Attendances over 4hrs Type 2',
#        'Attendances over 4hrs Other Department',
#        'Attendances over 4hrs Booked Appointments Type 1',
#        'Attendances over 4hrs Booked Appointments Type 2',
#        'Attendances over 4hrs Booked Appointments Other Department',
#        'Patients who have waited 4-12 hs from DTA to admission',
#        'Patients who have waited 12+ hrs from DTA to admission',
#        'Emergency admissions via A&E - Type 1',
#        'Emergency admissions via A&E - Type 2',
#        'Emergency admissions via A&E - Other A&E department',
#        'Other emergency admissions'],
#       dtype='object')

# %%
import pandas as pd
import glob

path = "/kaggle/input/datasets/alirezaderavi98/a-and-e-overcrowding-monthly-nhs/"   

all_files = glob.glob(path + "*.csv")

dfs = []

for file in all_files:
    try:
        df = pd.read_csv(file)

        if "A&E attendances Type 1" in df.columns:
            
            df["Date"] = pd.to_datetime(df["Period"], errors="coerce")

            df = df[
df.columns
            ]

            dfs.append(df)

    except Exception as e:
        print(f"Error reading {file}: {e}")

final_df = pd.concat(dfs, ignore_index=True)

final_df = final_df.sort_values("Date")

final_df = final_df.reset_index(drop=True)

final_df.to_csv("A&E_Monthly_Master.csv", index=False)

print("Done! File saved as A&E_Monthly_Master.csv")
# Out:
# Done! File saved as A&E_Monthly_Master.csv
# /tmp/ipykernel_16/2143864057.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Period"], errors="coerce")
# /tmp/ipykernel_16/2143864057.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Period"], errors="coerce")
# /tmp/ipykernel_16/2143864057.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Period"], errors="coerce")
# /tmp/ipykernel_16/2143864057.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Period"], errors="coerce")
# /tmp/ipykernel_16/2143864057.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Period"], errors="coerce")
# /tmp/ipykernel_16/2143864057.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Period"], errors="coerce")
# /tmp/ipykernel_16/2143864057.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Period"], errors="coerce")
# /tmp/ipykernel_16/2143864057.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Period"], errors="coerce")
# /tmp/ipykernel_16/2143864057.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Period"], errors="coerce")
# /tmp/ipykernel_16/2143864057.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Period"], errors="coerce")
# /tmp/ipykernel_16/2143864057.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Period"], errors="coerce")
# /tmp/ipykernel_16/2143864057.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Period"], errors="coerce")

# %%
final_df
# Out:
#                     Period Org Code                    Parent Org  \
# 0     MSitAE-DECEMBER-2024    AQN04       NHS ENGLAND SOUTH EAST
# 1     MSitAE-DECEMBER-2024    G0Q0L            NHS ENGLAND LONDON
# 2     MSitAE-DECEMBER-2024    K6K0R            NHS ENGLAND LONDON
# 3     MSitAE-DECEMBER-2024      RBT       NHS ENGLAND NORTH WEST
# 4     MSitAE-DECEMBER-2024      RJ8       NHS ENGLAND SOUTH WEST
# ...                    ...      ...                           ...
# 2379    MSitAE-AUGUST-2024      RJZ            NHS ENGLAND LONDON
# 2380    MSitAE-AUGUST-2024      RWG  NHS ENGLAND EAST OF ENGLAND
# 2381    MSitAE-AUGUST-2024      RM3       NHS ENGLAND NORTH WEST
# 2382    MSitAE-AUGUST-2024      RHU       NHS ENGLAND SOUTH EAST
# 2383                 TOTAL    TOTAL                         TOTAL
#
#                                                Org name  \
# 0                                     PHL LYMINGTON UTC
# 1                                  BARKING HOSPITAL UTC
# 2                            HAROLD WOOD POLYCLINIC UTC
# 3           MID CHESHIRE HOSPITALS NHS FOUNDATION TRUST
# 4             CORNWALL PARTNERSHIP NHS FOUNDATION TRUST
# ...                                                 ...
# 2379       KING'S COLLEGE HOSPITAL NHS FOUNDATION TRUST
# 2380    WEST HERTFORDSHIRE TEACHING HOSPITALS NHS TRUST
# 2381        NORTHERN CARE ALLIANCE NHS FOUNDATION TRUST
# 2382  PORTSMOUTH HOSPITALS UNIVERSITY NATIONAL HEALT...
# 2383                                              TOTAL
#
#       A&E attendances Type 1  A&E attendances Type 2  \
# 0                          0                       0
# 1                          0                       0
# 2                          0                       0
# 3                       7274                       0
# 4                          0                       0
# ...                      ...                     ...
# 2379                   14582                       0
# 2380                    7704                       0
# 2381                   23316                       0
# 2382                    9425                     762
# 2383                 1292332                   47731
#
#       A&E attendances Other A&E Department  \
# 0                                     2808
# 1                                     2841
# 2                                     2880
# 3                                     2684
# 4                                        0
# ...                                    ...
# 2379                                  7961
# 2380                                  7134
# 2381                                  8184
# 2382                                  2991
# 2383                                746162
#
#       A&E attendances Booked Appointments Type 1  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 2379                                          65
# 2380                                           0
# 2381                                           0
# 2382                                        1367
# 2383                                       27825
#
#       A&E attendances Booked Appointments Type 2  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 2379                                           0
# 2380                                           0
# 2381                                           0
# 2382                                           0
# 2383                                         656
#
#       A&E attendances Booked Appointments Other Department  ...  \
# 0                                                    13     ...
# 1                                                     0     ...
# 2                                                     0     ...
# 3                                                    62     ...
# 4                                                     0     ...
# ...                                                 ...     ...
# 2379                                               1149     ...
# 2380                                                834     ...
# 2381                                                  0     ...
# 2382                                                783     ...
# 2383                                              46085     ...
#
#       Emergency admissions via A&E - Type 2  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
# ...                                     ...
# 2379                                      0
# 2380                                      0
# 2381                                      0
# 2382                                      0
# 2383                                   1300
#
#       Emergency admissions via A&E - Other A&E department  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     4
# ...                                                 ...
# 2379                                                  0
# 2380                                                  0
# 2381                                                298
# 2382                                                  0
# 2383                                               4661
#
#       Other emergency admissions  Date  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0                              0   NaT          NaN          NaN          NaN
# 1                              0   NaT          NaN          NaN          NaN
# 2                              0   NaT          NaN          NaN          NaN
# 3                           1048   NaT          NaN          NaN          NaN
# 4                             74   NaT          NaN          NaN          NaN
# ...                          ...   ...          ...          ...          ...
# 2379                         413   NaT          NaN          NaN          NaN
# 2380                         549   NaT          NaN          NaN          NaN
# 2381                        1727   NaT          NaN          NaN          NaN
# 2382                        2373   NaT          NaN          NaN          NaN
# 2383                      129118   NaT          NaN          NaN          NaN
#
#       Unnamed: 25  Unnamed: 26   a
# 0             NaN          NaN NaN
# 1             NaN          NaN NaN
# 2             NaN          NaN NaN
# 3             NaN          NaN NaN
# 4             NaN          NaN NaN
# ...           ...          ...  ..
# 2379          NaN          NaN NaN
# 2380          NaN          NaN NaN
# 2381          NaN          NaN NaN
# 2382          NaN          NaN NaN
# 2383          NaN          NaN NaN
#
# [2384 rows x 29 columns]
